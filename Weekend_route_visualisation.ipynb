# %%
import numpy as np
import pandas as pd 
import folium
import random

ORSkey = '5b3ce3597851110001cf624806f3128b970645508bf9fdeae458da34'

locations = pd.read_csv("WoolworthsLocations.csv")
nodes = pd.read_csv("Demands as CSV.csv")
coords = locations[['Long', 'Lat']] # Mapping packages work with Long, Lat arrays
coords = coords.to_numpy().tolist() # Make the arrays into a list of lists.
# Folium, however, requires Lat, Long arrays - so a reversal is needed.
# coords[0] is the warehouse
m = folium.Map(location = list(reversed(coords[2])), zoom_start=10)
folium.Marker(list(reversed(coords[0])), popup = locations.Store[0], icon = folium.Icon(color = 'black')).add_to(m)
for i in range(0, len(coords)):
    if locations.Type[i] == "Countdown":
        iconCol = "green"
    elif locations.Type[i] == "FreshChoice":
        iconCol = "blue"
    elif locations.Type[i] == "SuperValue":
        iconCol = "red"
    elif locations.Type[i] == "Countdown Metro":
        iconCol = "orange"
    elif locations.Type[i] == "Distribution Centre":
        iconCol = "black"
    folium.Marker(list(reversed(coords[i])), popup = locations.Store[i], icon = folium.Icon(color = iconCol)).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import openrouteservice as ors
# Boot up client to OpenRouteService
client = ors.Client(key=ORSkey)
route1 = client.directions(
        coordinates = [coords[55], coords[41]], # Distribution Centre to Victoria Street W to Auckland City

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route2 = client.directions(
        coordinates = [coords[55], coords[4], coords[12], coords[16], coords[19]], # Distribution Centre to Onehunga to Ponsonby 

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route3 = client.directions(
        coordinates = [coords[55], coords[14], coords[17], coords[18], coords[50]], # Distribution Centre to Greenlane to St Lukes

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route4 = client.directions(
        coordinates = [coords[55], coords[39], coords[40], coords[43], coords[48]], # Distribution Centre to Grey Lynn to Grey Lynn Central

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route5 = client.directions(
        coordinates = [coords[55], coords[21]], # Distribution Centre to Mt Eden

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route6 = client.directions(
        coordinates = [coords[55], coords[22]], # Distribution Centre to Mangere East to Manurewa to 

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route7 = client.directions(
        coordinates = [coords[55], coords[36], coords[51], coords[54], coords[32]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route8 = client.directions(
        coordinates = [coords[55], coords[2], coords[13], coords[15], coords[27]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route9 = client.directions(
        coordinates = [coords[55], coords[3], coords[7], coords[11], coords[49]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route10 = client.directions(
        coordinates = [coords[55], coords[6], coords[20], coords[52], coords[34]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route11 = client.directions(
        coordinates = [coords[55], coords[30], coords[35], coords[46], coords[37]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route12 = client.directions(
        coordinates = [coords[55], coords[26], coords[33], coords[44], coords[47]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route13 = client.directions(
        coordinates = [coords[55], coords[5]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route14 = client.directions(
        coordinates = [coords[55], coords[38]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route15 = client.directions(
        coordinates = [coords[55], coords[0], coords[23], coords[24], coords[25]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route16 = client.directions(
        coordinates = [coords[55], coords[1], coords[9], coords[10], coords[53]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route17 = client.directions(
        coordinates = [coords[55], coords[8], coords[31], coords[42], coords[45]], # Distribution Centre to Countdown

        # We can have more than two coords - it will generate a path between those
        profile = 'driving-hgv', # can be driving-car, driving-hgv, etc. format='geojson',
        format = 'geojson',
        validate = False
        )
route = [route1, route2, route3, route4, route5, route6, route7, route8, route9, route10, route11, route12, route13,
        route14, route15, route16, route17]

# %%
chars = '0123456789ABCDEF'
for selected_route in route:
    colour = '#'+''.join(random.sample(chars,6))
    folium.PolyLine(locations = [list(reversed(coord))
                              for coord in selected_route['features'][0]['geometry']['coordinates']],
                                                                                            color = colour).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save("Weekend_SelectedRoutes.html")
