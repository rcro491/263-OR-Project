# %%
import numpy as np
import pandas as pd 
import folium
import random

ORSkey = '5b3ce3597851110001cf624806f3128b970645508bf9fdeae458da34'

locations = pd.read_csv("WoolworthsLocations.csv")
nodes = pd.read_csv("Demands as CSV.csv")
coords = locations[['Long', 'Lat']] # Mapping packages work with Long, Lat arrays
coords = coords.to_numpy().tolist() # Make the arrays into a list of lists.
# Folium, however, requires Lat, Long arrays - so a reversal is needed.
# coords[0] is the warehouse
map = folium.Map(location = list(reversed(coords[2])), zoom_start=10)
folium.Marker(list(reversed(coords[0])), popup = locations.Store[0], icon = folium.Icon(color = 'black')).add_to(m)
for i in range(0, len(coords)):
    if locations.Type[i] == "Countdown":
        iconCol = "green"
    elif locations.Type[i] == "FreshChoice":
        iconCol = "blue"
    elif locations.Type[i] == "SuperValue":
        iconCol = "red"
    elif locations.Type[i] == "Countdown Metro":
        iconCol = "orange"
    elif locations.Type[i] == "Distribution Centre":
        iconCol = "black"
    folium.Marker(list(reversed(coords[i])), popup = locations.Store[i], icon = folium.Icon(color = iconCol)).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
 import openrouteservice as ors
# Boot up client to OpenRouteService
Client = ors.Client(key=ORSkey)
route1 = Client.directions(
        coordinates = [coords[55], coords[53], coords[1]],
        profile = 'driving-hgv', 
        format = 'geojson',
        validate = False
        )
route2 = Client.directions(
        coordinates = [coords[55], coords[37], coords[41]], 
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route3 = Client.directions(
        coordinates = [coords[55], coords[8], coords[45]],
        profile = 'driving-hgv', 
        format = 'geojson',
        validate = False
        )
route4 = Client.directions(
        coordinates = [coords[55], coords[9], coords[10]],
        profile = 'driving-hgv', 
        format = 'geojson',
        validate = False
        )
route5 = Client.directions(
        coordinates = [coords[55], coords[21], coords[25], coords[64]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route6 = Client.directions(
        coordinates = [coords[55], coords[29], coords[32]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route7 = Client.directions(
        coordinates = [coords[55], coords[34], coords[52]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route8 = Client.directions(
        coordinates = [coords[55], coords[0], coords[22]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route9 = Client.directions(
        coordinates = [coords[55], coords[4], coords[16], coords[56]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route10 = Client.directions(
        coordinates = [coords[55], coords[36], coords[50]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route11 = Client.directions(
        coordinates = [coords[55], coords[12], coords[63], coords[65]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route12 = Client.directions(
        coordinates = [coords[55], coords[14], coords[17], coords[60]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route13 = Client.directions(
        coordinates = [coords[55], coords[18], coords[19], coords[61]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route14 = Client.directions(
        coordinates = [coords[55], coords[51], coords[54], coords[58]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route15 = Client.directions(
        coordinates = [coords[55], coords[3], coords[7]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route16 = Client.directions(
        coordinates = [coords[55], coords[23], coords[24], coords[62]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route17 = Client.directions(
        coordinates = [coords[55], coords[6], coords[20]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route18 = Client.directions(
        coordinates = [coords[55], coords[30], coords[49]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route19 = Client.directions(
        coordinates = [coords[55], coords[11], coords[28], coords[59]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route20 = Client.directions(
        coordinates = [coords[55], coords[39], coords[43]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route21 = Client.directions(
        coordinates = [coords[55], coords[35], coords[46]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route22 = Client.directions(
        coordinates = [coords[55], coords[40], coords[48]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route23 = Client.directions(
        coordinates = [coords[55], coords[2], coords[13], coords[57]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route24 = Client.directions(
        coordinates = [coords[55], coords[15], coords[27]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route25 = Client.directions(
        coordinates = [coords[55], coords[38], coords[5]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route26 = Client.directions(
        coordinates = [coords[55], coords[26], coords[47]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route27 = Client.directions(
        coordinates = [coords[55], coords[33], coords[44]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )
route28 = Client.directions(
        coordinates = [coords[55], coords[31], coords[42]],
        profile = 'driving-hgv',
        format = 'geojson',
        validate = False
        )

# %%
route = [route1, route2, route3, route4, route5, route6, route7, route8, route9, route10, route11, route12, route13,
        route14, route15, route16, route17, route18, route19, route20, route21, route22, route23, route24, route25,
        route26, route27, route28]

# %%
chars = '0123456789ABCDEF'
for i in range(len(route)):
    selected_route = route[i]
    colour = '#'+''.join(random.sample(chars,6))
    folium.PolyLine(locations = [list(reversed(coord))
                              for coord in selected_route['features'][0]['geometry']['coordinates']],
                                                                                            color = colour).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save("Weekday_SelectedRoutes.html")
